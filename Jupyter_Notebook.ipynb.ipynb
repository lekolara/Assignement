# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Lara Leko**
#
# Student and future researcher

# %% [markdown]
# *Data science interests me because i want to know what we can learn from data and how it can improve our lives*

# %% [markdown]
# ### The following code calculates factorials

# %%
n=1
f=5
for i in range(1,f+1):
    n=n*i
print("5!=",n)
# Out:
# 5!= 120

# %% [markdown]
# ------------
# - blue triangle
# - orange circle
# - black square
#
# ![WKandinsky.jpg](attachment:906f35cc-acf6-432f-8df3-d5531e1fe6d9.jpg)
